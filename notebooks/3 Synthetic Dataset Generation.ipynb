# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except ImportError:
    pass

# %%
import os
def get_root_dir():
    if os.path.exists('/content/drive/MyDrive/BT4012-Project/Notebooks'):
        return '/content/drive/MyDrive/BT4012-Project/Notebooks'
    else:
        return './'

print(get_root_dir())
os.chdir(get_root_dir())
