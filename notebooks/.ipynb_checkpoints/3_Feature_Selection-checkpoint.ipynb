# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/2_cleaned_dataset.csv', index_col=0)
df.head()
# Out:
#    is_fraud  avg_time_between_sent_txns  avg_time_between_received_txns  \
# 0         0                      844.26                         1093.71
# 1         0                    12709.07                         2958.44
# 2         0                   246194.54                         2434.02
# 3         0                    10219.60                        15785.09
# 4         0                       36.61                        10707.77
#
#    first_and_last_txns_time_diff  num_sent_txns  num_received_txns  \
# 0                      704785.63            721                 89
# 1                     1218216.73             94                  8
# 2                      516729.30              2                 10
# 3                      397555.90             25                  9
# 4                      382472.42           4598                 20
#
#    num_create_contracts_txns  num_unique_senders_to_acc  \
# 0                          0                         40
# 1                          0                          5
# 2                          0                         10
# 3                          0                          7
# 4                          1                          7
#
#    num_unique_recipients_from_acc  min_value_received  max_value_received  \
# 0                             118            0.000000           45.806785
# 1                              14            0.000000            2.613269
# 2                               2            0.113119            1.165453
# 3                              13            0.000000          500.000000
# 4                              19            0.000000           12.802411
#
#    avg_value_received  min_value_sent  max_value_sent  avg_value_sent  \
# 0            6.589513            0.00       31.220000        1.200681
# 1            0.385685            0.00        1.800000        0.032844
# 2            0.358906            0.05        3.538616        1.794308
# 3           99.488840            0.00      450.000000       70.001834
# 4            2.671095            0.00        9.000000        0.022688
#
#    total_transactions  total_ether_sent  total_ether_received  \
# 0                 810        865.691093            586.466675
# 1                 102          3.087297              3.085478
# 2                  12          3.588616              3.589057
# 3                  34       1750.045862            895.399559
# 4                4619        104.318883             53.421897
#
#    total_ERC20_txns  total_ERC20_sent_in_ether  \
# 0             265.0               3.560317e+07
# 1               8.0               2.260809e+00
# 2               8.0               0.000000e+00
# 3              14.0               1.141223e+04
# 4              42.0               1.235399e+05
#
#    total_ERC20_sent_contract_in_ether  ERC20_num_unique_recipients_from_acc  \
# 0                                 0.0                                  30.0
# 1                                 0.0                                   1.0
# 2                                 0.0                                   0.0
# 3                                 0.0                                   2.0
# 4                                 0.0                                   4.0
#
#    ERC20_num_unique_senders_to_acc  ERC20_num_unique_senders_contract_to_acc  \
# 0                             54.0                                      58.0
# 1                              5.0                                       7.0
# 2                              7.0                                       8.0
# 3                             11.0                                      11.0
# 4                             23.0                                      27.0
#
#    ERC20_min_value_sent  ERC20_max_value_sent  ERC20_avg_value_sent  \
# 0              0.000000          1.683100e+07         271779.920000
# 1              2.260809          2.260809e+00              2.260809
# 2              0.000000          0.000000e+00              0.000000
# 3            100.000000          9.029231e+03           3804.076893
# 4              0.000000          4.500000e+04          13726.659220
#
#    has_sent_ERC20  has_received_ERC20  has_created_contracts  \
# 0               1                   1                      0
# 1               1                   1                      0
# 2               0                   1                      0
# 3               1                   1                      0
# 4               1                   1                      1
#
#    total_ether_volume  num_sent_to_total_txns_ratio  \
# 0         1452.157768                      0.890123
# 1            6.172775                      0.921569
# 2            7.177672                      0.166667
# 3         2645.445421                      0.735294
# 4          157.740779                      0.995454
#
#    num_received_to_total_txns_ratio  total_value_sent_ratio  \
# 0                          0.109877                0.403859
# 1                          0.078431                0.499853
# 2                          0.833333                0.500031
# 3                          0.264706                0.338468
# 4                          0.004330                0.338669
#
#    total_value_received_ratio
# 0                    0.596141
# 1                    0.500147
# 2                    0.499969
# 3                    0.661532
# 4                    0.661331

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


X = df.drop(['is_fraud'],axis=1)
y = df['is_fraud']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y)

baseline_rf = RandomForestClassifier()
baseline_rf.fit(X_train, y_train)
y_pred = baseline_rf.predict(X_test)
rf_cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = rf_cm.ravel()

accuracy = (tp + tn) / (tn + fp + fn + tp)
recall = tp / (tp + fn)
precision = tp / (tp + fp)
f1 = 2 * precision * recall / (precision + recall)


plt.figure(figsize=(9,9))
sns.heatmap(rf_cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy: {0:.5f}\n Recall: {1:.5f}\n Precision: {2:.5f}\n F1: {3:.5f}'.format(accuracy,recall, precision, f1)
plt.title(all_sample_title, size=15)
plt.show()

# %%
importances = baseline_rf.feature_importances_
std = np.std([tree.feature_importances_ for tree in baseline_rf.estimators_], axis=0)
forest_importances = pd.Series(importances, index=X_train.columns).sort_values(ascending=False)


fig, ax = plt.subplots(figsize=(25,10))
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
def rank_feature_importances(feature_set):
  rf = RandomForestClassifier()
  rf.fit(X_train[feature_set], y_train)
  importances = rf.feature_importances_
  sorted_importance = pd.Series(importances, index=feature_set).sort_values(ascending=False)

  features_ranked = sorted_importance.index.tolist()
  importance_ranking={}
  for index, feature in enumerate(features_ranked):
    importance_ranking[feature] = index

  return importance_ranking

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
# Variance Inflation Factor (VIF) Inference
# VIF threshold: 2.5; https://corporatefinanceinstitute.com/resources/data-science/variance-inflation-factor-vif/

def get_vif(features, df):
    
    X = df[features]
    # the calculation of variance inflation requires a constant
    X['intercept'] = 1
    
    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif["Variable"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif[vif['Variable']!='intercept']
    return vif

def drop_feature(df, importance_ranking):
    vif_df = get_vif(df.columns, df).sort_values('VIF', ascending=False)
    feature0 = vif_df.iloc[0]['Variable']
    feature1 = vif_df.iloc[1]['Variable']
    if importance_ranking[feature0] < importance_ranking[feature1]:
      return vif_df, df.drop(feature1, axis=1)
    return vif_df, df.drop(feature0,axis=1)

def vif_iterate(df, min_features_count, vif_cutoff, verbose=False):
    while len(df.columns) > min_features_count:
        vif_df = get_vif(df.columns,df).sort_values('VIF', ascending=False)
        importance_ranking = rank_feature_importances(df.columns)
        if verbose:
          print(vif_df)
          print()
        if np.sum(vif_df['VIF'] >= vif_cutoff)==0:
            break
        _, df = drop_feature(df, importance_ranking)
    return get_vif(df.columns,df).sort_values('VIF', ascending=False), df

# %%
vif_df,_= vif_iterate(X_train, 10,2.5)
vif_columns = vif_df['Variable'].reset_index(drop=True).to_numpy()
print(vif_df)
print()
print(vif_columns)
# Out:
#                                     Variable       VIF
# 14           ERC20_num_unique_senders_to_acc  2.343745
# 10                        total_transactions  2.232435
# 15  ERC20_num_unique_senders_contract_to_acc  2.025058
# 19                    total_value_sent_ratio  1.941178
# 9                             avg_value_sent  1.918720
# 18          num_received_to_total_txns_ratio  1.896241
# 7                             min_value_sent  1.801393
# 13      ERC20_num_unique_recipients_from_acc  1.692437
# 3                  num_unique_senders_to_acc  1.652802
# 6                         max_value_received  1.577108
# 11                      total_ether_received  1.563577
# 4             num_unique_recipients_from_acc  1.496859
# 2              first_and_last_txns_time_diff  1.454368
# 20                total_value_received_ratio  1.209021
# 17                            has_sent_ERC20  1.204878
# 8                             max_value_sent  1.152422
# 1             avg_time_between_received_txns  1.142460
# 5                         min_value_received  1.117629
# 0                 avg_time_between_sent_txns  1.069834
# 12        total_ERC20_sent_contract_in_ether  1.023656
# 16                      ERC20_max_value_sent  1.001079
#
# ['ERC20_num_unique_senders_to_acc' 'total_transactions'
#  'ERC20_num_unique_senders_contract_to_acc' 'total_value_sent_ratio'
#  'avg_value_sent' 'num_received_to_total_txns_ratio' 'min_value_sent'
#  'ERC20_num_unique_recipients_from_acc' 'num_unique_senders_to_acc'
#  'max_value_received' 'total_ether_received'
#  'num_unique_recipients_from_acc' 'first_and_last_txns_time_diff'
#  'total_value_received_ratio' 'has_sent_ERC20' 'max_value_sent'
#  'avg_time_between_received_txns' 'min_value_received'
#  'avg_time_between_sent_txns' 'total_ERC20_sent_contract_in_ether'
#  'ERC20_max_value_sent']

# %%
selected_features = vif_columns.tolist()
selected_features
# Out:
# ['ERC20_num_unique_senders_to_acc',
#  'total_transactions',
#  'ERC20_num_unique_senders_contract_to_acc',
#  'total_value_sent_ratio',
#  'avg_value_sent',
#  'num_received_to_total_txns_ratio',
#  'min_value_sent',
#  'ERC20_num_unique_recipients_from_acc',
#  'num_unique_senders_to_acc',
#  'max_value_received',
#  'total_ether_received',
#  'num_unique_recipients_from_acc',
#  'first_and_last_txns_time_diff',
#  'total_value_received_ratio',
#  'has_sent_ERC20',
#  'max_value_sent',
#  'avg_time_between_received_txns',
#  'min_value_received',
#  'avg_time_between_sent_txns',
#  'total_ERC20_sent_contract_in_ether',
#  'ERC20_max_value_sent']

# %%
plt.figure(figsize=(20,16))
corr = X_train[selected_features].corr().abs()
mask = np.triu(np.ones_like(corr, dtype=bool))
sns.heatmap(corr,annot=True, mask=mask)
plt.show()

# %%
# Pearson Coeff Threshold: 0.7
# https://blog.clairvoyantsoft.com/correlation-and-collinearity-how-they-can-make-or-break-a-model-9135fbe6936a
# No features to remove

# %%
selected_features = ['is_fraud'] + selected_features
selected_features
# Out:
# ['is_fraud',
#  'ERC20_num_unique_senders_to_acc',
#  'total_transactions',
#  'ERC20_num_unique_senders_contract_to_acc',
#  'total_value_sent_ratio',
#  'avg_value_sent',
#  'num_received_to_total_txns_ratio',
#  'min_value_sent',
#  'ERC20_num_unique_recipients_from_acc',
#  'num_unique_senders_to_acc',
#  'max_value_received',
#  'total_ether_received',
#  'num_unique_recipients_from_acc',
#  'first_and_last_txns_time_diff',
#  'total_value_received_ratio',
#  'has_sent_ERC20',
#  'max_value_sent',
#  'avg_time_between_received_txns',
#  'min_value_received',
#  'avg_time_between_sent_txns',
#  'total_ERC20_sent_contract_in_ether',
#  'ERC20_max_value_sent']

# %%
output_df = df[selected_features]

# %%
output_df.head()
# Out:
#    is_fraud  ERC20_num_unique_senders_to_acc  total_transactions  \
# 0         0                             54.0                 810
# 1         0                              5.0                 102
# 2         0                              7.0                  12
# 3         0                             11.0                  34
# 4         0                             23.0                4619
#
#    ERC20_num_unique_senders_contract_to_acc  total_value_sent_ratio  \
# 0                                      58.0                0.403859
# 1                                       7.0                0.499853
# 2                                       8.0                0.500031
# 3                                      11.0                0.338468
# 4                                      27.0                0.338669
#
#    avg_value_sent  num_received_to_total_txns_ratio  min_value_sent  \
# 0        1.200681                          0.109877            0.00
# 1        0.032844                          0.078431            0.00
# 2        1.794308                          0.833333            0.05
# 3       70.001834                          0.264706            0.00
# 4        0.022688                          0.004330            0.00
#
#    ERC20_num_unique_recipients_from_acc  num_unique_senders_to_acc  \
# 0                                  30.0                         40
# 1                                   1.0                          5
# 2                                   0.0                         10
# 3                                   2.0                          7
# 4                                   4.0                          7
#
#    max_value_received  total_ether_received  num_unique_recipients_from_acc  \
# 0           45.806785            586.466675                             118
# 1            2.613269              3.085478                              14
# 2            1.165453              3.589057                               2
# 3          500.000000            895.399559                              13
# 4           12.802411             53.421897                              19
#
#    first_and_last_txns_time_diff  total_value_received_ratio  has_sent_ERC20  \
# 0                      704785.63                    0.596141               1
# 1                     1218216.73                    0.500147               1
# 2                      516729.30                    0.499969               0
# 3                      397555.90                    0.661532               1
# 4                      382472.42                    0.661331               1
#
#    max_value_sent  avg_time_between_received_txns  min_value_received  \
# 0       31.220000                         1093.71            0.000000
# 1        1.800000                         2958.44            0.000000
# 2        3.538616                         2434.02            0.113119
# 3      450.000000                        15785.09            0.000000
# 4        9.000000                        10707.77            0.000000
#
#    avg_time_between_sent_txns  total_ERC20_sent_contract_in_ether  \
# 0                      844.26                                 0.0
# 1                    12709.07                                 0.0
# 2                   246194.54                                 0.0
# 3                    10219.60                                 0.0
# 4                       36.61                                 0.0
#
#    ERC20_max_value_sent
# 0          1.683100e+07
# 1          2.260809e+00
# 2          0.000000e+00
# 3          9.029231e+03
# 4          4.500000e+04

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9816 entries, 0 to 9840
# Data columns (total 22 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   is_fraud                                  9816 non-null   int64
#  1   ERC20_num_unique_senders_to_acc           9816 non-null   float64
#  2   total_transactions                        9816 non-null   int64
#  3   ERC20_num_unique_senders_contract_to_acc  9816 non-null   float64
#  4   total_value_sent_ratio                    9816 non-null   float64
#  5   avg_value_sent                            9816 non-null   float64
#  6   num_received_to_total_txns_ratio          9816 non-null   float64
#  7   min_value_sent                            9816 non-null   float64
#  8   ERC20_num_unique_recipients_from_acc      9816 non-null   float64
#  9   num_unique_senders_to_acc                 9816 non-null   int64
#  10  max_value_received                        9816 non-null   float64
#  11  total_ether_received                      9816 non-null   float64
#  12  num_unique_recipients_from_acc            9816 non-null   int64
#  13  first_and_last_txns_time_diff             9816 non-null   float64
#  14  total_value_received_ratio                9816 non-null   float64
#  15  has_sent_ERC20                            9816 non-null   int64
#  16  max_value_sent                            9816 non-null   float64
#  17  avg_time_between_received_txns            9816 non-null   float64
#  18  min_value_received                        9816 non-null   float64
#  19  avg_time_between_sent_txns                9816 non-null   float64
#  20  total_ERC20_sent_contract_in_ether        9816 non-null   float64
#  21  ERC20_max_value_sent                      9816 non-null   float64
# dtypes: float64(17), int64(5)
# memory usage: 1.7 MB

# %%
output_df.to_csv('../data/3_final_dataset.csv', index=False)
